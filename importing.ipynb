# %%
import pandas as pd
import numpy as np

# %%
dat1 = pd.read_json('yelp_dataset/yelp_academic_dataset_business.json', lines=True)

# %%
dat1.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# ...

# %%
dat1.city.value_counts()
# Out:
# city
# Philadelphia      14569
# Tucson             9250
# Tampa              9050
# Indianapolis       7540
# Nashville          6971
#                   ...
# Gentilly              1
# pennsauken            1
# Hamiltion             1
# Newtown square        1
# Apollo beach          1
# Name: count, Length: 1416, dtype: int64

# %%
philly = dat1[dat1.city == 'Philadelphia']

# %%
philly.shape
philly.head()
# Out:
#                business_id                name        address          city  \
# 3   MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries    935 Race St  Philadelphia
# 15  MUTTqe8uqyMdBl186RmNeA            Tuna Bar    205 Race St  Philadelphia
# 19  ROeacJQwBeh05Rqg7F6TCg                 BAP  1224 South St  Philadelphia
# 28  QdN72BWoyFypdGJhhI5r7g             Bar One   767 S 9th St  Philadelphia
# 31  Mjboz24M9NlBeiOJKLEd_Q    DeSandro on Main   4105 Main St  Philadelphia
#
#    state postal_code   latitude  longitude  stars  review_count  is_open  \
# 3     PA       19107  39.955505 -75.155564    4.0            80        1
# 15    PA       19106  39.953949 -75.143226    4.0           245        1
# 19    PA       19147  39.943223 -75.162568    4.5           205        1
# 28    PA       19147  39.939825 -75.157447    4.0            65        0
# 31    PA       19127  40.022466 -75.218314    3.0            41        0
#
#                                            attributes  \
# ...

# %%
reviewsdat = pd.read_json('yelp_dataset/yelp_academic_dataset_review.json', lines=True)

# %%
# philly.to_csv('philly_businesses.csv', index=False)

# %%
reviewsdat.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      3       0      0     0
# 3      5       1      0     1
# 4      4       1      0     1
#
#                                                 text                date
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# ...

# %%
df_merged = pd.merge(philly, reviewsdat, on='business_id', how='right')

# %%
df_merged.head()
# Out:
#               business_id                        name  \
# 0  XQfwVwDr-v0ZS3_CbbE5Xw                         NaN
# 1  7ATYjTIgM3jUlt4UM3IypQ  Body Cycle Spinning Studio
# 2  YjUWPpI6HXG530lwP-fb2A                         NaN
# 3  kxX2SOes4o-D3ZQBkiMRfA                       Zaika
# 4  e4Vwtrqf-wpJfwesgvdgxQ                         NaN
#
#                     address          city state postal_code   latitude  \
# 0                       NaN           NaN   NaN         NaN        NaN
# 1  1923 Chestnut St, 2nd Fl  Philadelphia    PA       19119  39.952103
# 2                       NaN           NaN   NaN         NaN        NaN
# 3            2481 Grant Ave  Philadelphia    PA       19114  40.079848
# 4                       NaN           NaN   NaN         NaN        NaN
#
#    longitude  stars_x  review_count  ...  \
# 0        NaN      NaN           NaN  ...
# 1 -75.172753      5.0         144.0  ...
# 2        NaN      NaN           NaN  ...
# ...

# %%
merged2 = pd.merge(reviewsdat, philly, on='business_id', how='left')

# %%
merged2.shape
# Out:
# (6990280, 22)

# %%
merged2.head()
merged2.columns
# Out:
# Index(['review_id', 'user_id', 'business_id', 'stars_x', 'useful', 'funny',
#        'cool', 'text', 'date', 'name', 'address', 'city', 'state',
#        'postal_code', 'latitude', 'longitude', 'stars_y', 'review_count',
#        'is_open', 'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
merged2.to_csv('philly_reviews_merged.csv', index=False)
